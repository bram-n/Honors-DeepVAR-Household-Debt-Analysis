# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /opt/homebrew/lib/python3.11/site-packages/gluonts/json.py:101: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(

# %%
import pandas as pd

urls = ["https://stats.bis.org/api/v2/data/dataflow/BIS/WS_TC/2.0/.4T+5A+5R+AR+AT+AU+BE+BR+CA+CH+CL+CN+CO+CZ+DE+DK+ES+FI+FR+G2+GB+GR+HK+HU+ID+IE+IL+IN+IT+JP+KR+LU+MX+MY+NL+NO+NZ+PL+PT+RU+SA+SE+SG+TH+TR+US+XM+ZA.H...770?format=csv"]

df = pd.concat([pd.read_csv(url) for url in urls])

# %%
unique_items = [
    'NZ', 'DE', 'GR', 'BR', 'TH', 'BE', 'TR', '5A', 'PL', 'NO', 'CZ', 'IT', 'KR', 
    'SG', 'HU', '5R', 'PT', 'IN', 'US', 'NL', 'LU', 'GB', 'ID', 'FI', 'SE', 'CL', 
    'IE', 'ZA', 'SA', 'MX', 'MY', 'FR', 'AR', 'AT', 'IL', 'CH', 'CN', 'ES', '4T', 
    'CO', 'CA', 'AU', 'G2', 'RU', 'DK', 'XM', 'HK', 'JP'
]
country_mapping = {
    'AL': 'Albania',
    'DZ': 'Algeria',
    'AR': 'Argentina',
    'AM': 'Armenia, Rep. of',
    'AU': 'Australia',
    'AT': 'Austria',
    'AZ': 'Azerbaijan, Rep. of',
    'BS': 'Bahamas, The',
    'BY': 'Belarus, Rep. of',
    'BE': 'Belgium',
    'BO': 'Bolivia',
    'BA': 'Bosnia and Herzegovina',
    'BW': 'Botswana',
    'BR': 'Brazil',
    'BN': 'Brunei Darussalam',
    'BG': 'Bulgaria',
    'CV': 'Cabo Verde',
    'CM': 'Cameroon',
    'CA': 'Canada',
    'CL': 'Chile',
    'HK': 'China, P.R.: Hong Kong',
    'MO': 'China, P.R.: Macao',
    'CN': 'China, P.R.: Mainland',
    'CO': 'Colombia',
    'CR': 'Costa Rica',
    'HR': 'Croatia, Rep. of',
    'CY': 'Cyprus',
    'CZ': 'Czech Rep.',
    'DK': 'Denmark',
    'DO': 'Dominican Rep.',
    'EC': 'Ecuador',
    'EG': 'Egypt, Arab Rep. of',
    'SV': 'El Salvador',
    'EE': 'Estonia, Rep. of',
    'EA': 'Euro Area',
    'FI': 'Finland',
    'FR': 'France',
    'GE': 'Georgia',
    'DE': 'Germany',
    'GH': 'Ghana',
    'GR': 'Greece',
    'GT': 'Guatemala',
    'HU': 'Hungary',
    'IS': 'Iceland',
    'IN': 'India',
    'ID': 'Indonesia',
    'IR': 'Iran, Islamic Rep. of',
    'IE': 'Ireland',
    'IL': 'Israel',
    'IT': 'Italy',
    'JM': 'Jamaica',
    'JP': 'Japan',
    'JO': 'Jordan',
    'KZ': 'Kazakhstan, Rep. of',
    'KE': 'Kenya',
    'KR': 'Korea, Rep. of',
    'XK': 'Kosovo, Rep. of',
    'KG': 'Kyrgyz Rep.',
    'LV': 'Latvia',
    'LS': 'Lesotho, Kingdom of',
    'LT': 'Lithuania',
    'LU': 'Luxembourg',
    'MY': 'Malaysia',
    'MT': 'Malta',
    'MU': 'Mauritius',
    'MX': 'Mexico',
    'MD': 'Moldova, Rep. of',
    'MN': 'Mongolia',
    'ME': 'Montenegro',
    'NA': 'Namibia',
    'NL': 'Netherlands, The',
    'NZ': 'New Zealand',
    'NI': 'Nicaragua',
    'NG': 'Nigeria',
    'MK': 'North Macedonia, Republic of',
    'NO': 'Norway',
    'PY': 'Paraguay',
    'PE': 'Peru',
    'PH': 'Philippines',
    'PL': 'Poland, Rep. of',
    'PT': 'Portugal',
    'QA': 'Qatar',
    'RO': 'Romania',
    'RU': 'Russian Federation',
    'RW': 'Rwanda',
    'WS': 'Samoa',
    'SA': 'Saudi Arabia',
    'SN': 'Senegal',
    'RS': 'Serbia, Rep. of',
    'SC': 'Seychelles',
    'SG': 'Singapore',
    'SK': 'Slovak Rep.',
    'SI': 'Slovenia, Rep. of',
    'ZA': 'South Africa',
    'ES': 'Spain',
    'LK': 'Sri Lanka',
    'LC': 'St. Lucia',
    'VC': 'St. Vincent and the Grenadines',
    'SE': 'Sweden',
    'CH': 'Switzerland',
    'TH': 'Thailand',
    'TT': 'Trinidad and Tobago',
    'TR': 'Türkiye, Rep of',
    'UG': 'Uganda',
    'UA': 'Ukraine',
    'GB': 'United Kingdom',
    'US': 'United States',
    'UY': 'Uruguay',
    'PS': 'West Bank and Gaza'
}

# Create a DataFrame from the unique items
df_unique = pd.DataFrame(unique_items, columns=['Code'])

# Map codes to countries
df_unique['Country'] = df_unique['Code'].map(country_mapping)

# %%
new_df = pd.merge(df, df_unique, left_on='BORROWERS_CTY', right_on='Code', how='left')

# %%
new_df
# Out:
#      FREQ BORROWERS_CTY TC_BORROWERS TC_LENDERS VALUATION  UNIT_TYPE  \
# 0       Q            SA            H          A         M        770
# 1       Q            SA            H          A         M        770
# 2       Q            SA            H          A         M        770
# 3       Q            SA            H          A         M        770
# 4       Q            SA            H          A         M        770
# ...   ...           ...          ...        ...       ...        ...
# 6797    Q            G2            H          A         M        770
# 6798    Q            G2            H          A         M        770
# 6799    Q            G2            H          A         M        770
# 6800    Q            G2            H          A         M        770
# 6801    Q            G2            H          A         M        770
#
#      TC_ADJUST COLLECTION  DECIMALS  UNIT_MULT  UNIT_MEASURE  \
# 0            A          E         1          0           367
# 1            A          E         1          0           367
# 2            A          E         1          0           367
# 3            A          E         1          0           367
# 4            A          E         1          0           367
# ...        ...        ...       ...        ...           ...
# 6797         A          E         1          0           367
# 6798         A          E         1          0           367
# 6799         A          E         1          0           367
# 6800         A          E         1          0           367
# 6801         A          E         1          0           367
#
#                                                TITLE_TS TIME_PERIOD  \
# 0     Saudi Arabia - Credit to Households and NPISHs...     1998-Q1
# 1     Saudi Arabia - Credit to Households and NPISHs...     1998-Q2
# 2     Saudi Arabia - Credit to Households and NPISHs...     1998-Q3
# 3     Saudi Arabia - Credit to Households and NPISHs...     1998-Q4
# 4     Saudi Arabia - Credit to Households and NPISHs...     1999-Q1
# ...                                                 ...         ...
# 6797  G20 (aggregate) - Credit to Households and NPI...     2023-Q2
# 6798  G20 (aggregate) - Credit to Households and NPI...     2023-Q3
# 6799  G20 (aggregate) - Credit to Households and NPI...     2023-Q4
# 6800  G20 (aggregate) - Credit to Households and NPI...     2024-Q1
# 6801  G20 (aggregate) - Credit to Households and NPI...     2024-Q2
#
#       OBS_VALUE OBS_STATUS  OBS_PRE_BREAK OBS_CONF Code       Country
# 0          17.1          A            NaN        F   SA  Saudi Arabia
# 1          18.0          A            NaN        F   SA  Saudi Arabia
# 2          19.1          A            NaN        F   SA  Saudi Arabia
# 3          19.7          A            NaN        F   SA  Saudi Arabia
# 4          19.7          A            NaN        F   SA  Saudi Arabia
# ...         ...        ...            ...      ...  ...           ...
# 6797       61.5          A            NaN        F   G2           NaN
# 6798       60.7          A            NaN        F   G2           NaN
# 6799       61.6          A            NaN        F   G2           NaN
# 6800       60.6          A            NaN        F   G2           NaN
# 6801       60.3          A            NaN        F   G2           NaN
#
# [6802 rows x 19 columns]

# %%
countries = ['Canada', 'Australia', 'Korea, Rep. of', 'United States']
df2 = new_df[new_df['Country'].isin(countries)]

df2 = df2.rename(columns={'OBS_VALUE': 'Household Debt'})

# %%
from datetime import datetime
def convert_quarter_to_start_datetime(quarter_str):
    year, quarter = quarter_str.split('-')
    year = int(year)
    quarter = int(quarter[1])  
    
    if quarter == 1:
        month = 1  # January
    elif quarter == 2:
        month = 4  # April
    elif quarter == 3:
        month = 7  # July
    elif quarter == 4:
        month = 10 # October

    return datetime(year, month, 1)

# Replace the 'TIME_PERIOD' column with the start dates
df2['TIME_PERIOD'] = df2['TIME_PERIOD'].apply(convert_quarter_to_start_datetime)

# %%
df3 = df2[df2['TIME_PERIOD'] >= '2000-01-01']
df3
# Out:
#      FREQ BORROWERS_CTY TC_BORROWERS TC_LENDERS VALUATION  UNIT_TYPE  \
# 1618    Q            US            H          A         M        770
# 1619    Q            US            H          A         M        770
# 1620    Q            US            H          A         M        770
# 1621    Q            US            H          A         M        770
# 1622    Q            US            H          A         M        770
# ...   ...           ...          ...        ...       ...        ...
# 6255    Q            AU            H          A         M        770
# 6256    Q            AU            H          A         M        770
# 6257    Q            AU            H          A         M        770
# 6258    Q            AU            H          A         M        770
# 6259    Q            AU            H          A         M        770
#
#      TC_ADJUST COLLECTION  DECIMALS  UNIT_MULT  UNIT_MEASURE  \
# 1618         A          E         1          0           367
# 1619         A          E         1          0           367
# 1620         A          E         1          0           367
# 1621         A          E         1          0           367
# 1622         A          E         1          0           367
# ...        ...        ...       ...        ...           ...
# 6255         A          E         1          0           367
# 6256         A          E         1          0           367
# 6257         A          E         1          0           367
# 6258         A          E         1          0           367
# 6259         A          E         1          0           367
#
#                                                TITLE_TS TIME_PERIOD  \
# 1618  United States - Credit to Households and NPISH...  2000-01-01
# 1619  United States - Credit to Households and NPISH...  2000-04-01
# 1620  United States - Credit to Households and NPISH...  2000-07-01
# 1621  United States - Credit to Households and NPISH...  2000-10-01
# 1622  United States - Credit to Households and NPISH...  2001-01-01
# ...                                                 ...         ...
# 6255  Australia - Credit to Households and NPISHs fr...  2023-04-01
# 6256  Australia - Credit to Households and NPISHs fr...  2023-07-01
# 6257  Australia - Credit to Households and NPISHs fr...  2023-10-01
# 6258  Australia - Credit to Households and NPISHs fr...  2024-01-01
# 6259  Australia - Credit to Households and NPISHs fr...  2024-04-01
#
#       Household Debt OBS_STATUS  OBS_PRE_BREAK OBS_CONF Code        Country
# 1618            69.5          A            NaN        F   US  United States
# 1619            69.7          A            NaN        F   US  United States
# 1620            70.4          A            NaN        F   US  United States
# 1621            70.8          A            NaN        F   US  United States
# 1622            70.6          A            NaN        F   US  United States
# ...              ...        ...            ...      ...  ...            ...
# 6255           110.3          A            NaN        F   AU      Australia
# 6256           109.9          A            NaN        F   AU      Australia
# 6257           110.0          A            NaN        F   AU      Australia
# 6258           110.6          A            NaN        F   AU      Australia
# 6259           111.5          A            NaN        F   AU      Australia
#
# [392 rows x 19 columns]

# %%
plt.figure(figsize=(10, 6))
for country in df3['Country'].unique():
    country_data = df3[df3['Country'] == country]
    plt.plot(country_data['TIME_PERIOD'], country_data['Household Debt'], 
             linestyle='-', linewidth=2, label=country)
plt.axhline(y=85, color='r', linestyle='--', linewidth=1, label='Household Debt = 85')

plt.title('Household Debt/GDP Over Time')
plt.xlabel('Time Period')
plt.ylabel('Household Debt')
plt.xticks(rotation=45)
plt.legend()

plt.tight_layout()
plt.show()
